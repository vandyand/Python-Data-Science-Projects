# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
train = pd.read_csv('train.csv')
holdout = pd.read_csv('test.csv')

# %%
total = pd.concat([train,holdout],ignore_index=True)
total.shape
# Out:
# (2919, 81)

# %%
train.shape
# Out:
# (1460, 81)

# %%
holdout.shape
# Out:
# (1459, 80)

# %%
total_null_cols = train.isnull().sum()==0

# %%
total = total.loc[:,total_null_cols]

# %%
total.loc[1460:,'SalePrice'] = 0

# %%
total.loc[total.loc[:,total.isnull().any()].isnull().any(axis=1),:]
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType  BsmtFinSF1  \
# 1555       725       499          0             3     1Fam         0.0
# 1915       810         0          0             1     1Fam         0.0
# 1945      1474         0          0             3     1Fam         0.0
# 2120       896         0          0             2     1Fam         NaN
# 2151      1518         0          0             2     1Fam      1035.0
# 2188      3820         0          0             5     1Fam         0.0
# 2216       733         0          0             2     1Fam         0.0
# 2250      1150       686          0             4     1Fam         0.0
# 2473       866       504          0             3     1Fam         0.0
# 2489      1176         0          0             3     1Fam       190.0
# 2576       942       886          0             3     1Fam       548.0
# 2904      1600         0          0             3     1Fam         0.0
#
#       BsmtFinSF2  BsmtFullBath  BsmtHalfBath  BsmtUnfSF CentralAir Condition1  \
# 1555         0.0           0.0           0.0      689.0          N       Norm
# 1915         0.0           0.0           0.0        0.0          N       Norm
# 1945         0.0           0.0           0.0     1632.0          Y      Feedr
# 2120         NaN           NaN           NaN        NaN          Y      Feedr
# 2151         0.0           1.0           0.0      545.0          Y       Norm
# 2188         0.0           NaN           NaN        0.0          Y       Norm
# 2216         0.0           0.0           0.0        0.0          N       Norm
# 2250         0.0           0.0           0.0      686.0          Y       Norm
# 2473         0.0           0.0           0.0      771.0          Y     Artery
# 2489       873.0           1.0           0.0       95.0          Y      Feedr
# 2576         0.0           0.0           0.0      311.0          Y       Norm
# 2904         0.0           0.0           0.0        0.0          Y     Artery
#
#      Condition2  EnclosedPorch ExterCond ExterQual Exterior1st Exterior2nd  \
# 1555       Norm            248        TA        TA     Wd Sdng     Wd Sdng
# 1915       Norm              0        Fa        Fa     Wd Sdng     Wd Sdng
# 1945       Norm            144        TA        TA     BrkFace     BrkFace
# 2120       Norm              0        TA        TA     MetalSd      CBlock
# 2151       Norm              0        TA        TA         NaN         NaN
# 2188       Norm              0        TA        TA     Plywood     Plywood
# 2216       Norm              0        Po        Fa     AsbShng     VinylSd
# 2250       Norm              0        TA        TA     Wd Sdng     Wd Sdng
# 2473       Norm              0        Fa        Fa     Wd Sdng     Wd Sdng
# 2489       Norm              0        TA        TA     Plywood     Plywood
# 2576       Norm            212        TA        TA     Wd Sdng     Plywood
# 2904       Norm            135        Fa        TA      CBlock     VinylSd
#
#       Fireplaces Foundation  FullBath Functional  GarageArea  GarageCars  \
# 1555           0     BrkTil         1        Mod       180.0         1.0
# 1915           0     CBlock         1       Min1       280.0         1.0
# 1945           2     CBlock         1       Min2       495.0         2.0
# 2120           0      PConc         1        Typ       280.0         1.0
# 2151           2      PConc         1        Typ         0.0         0.0
# 2188           2       Slab         3        Typ       624.0         2.0
# 2216           0       Slab         1        NaN       487.0         2.0
# 2250           0     BrkTil         2       Maj1       288.0         1.0
# 2473           0     CBlock         2        NaN       264.0         1.0
# 2489           2     CBlock         1        Typ       303.0         1.0
# 2576           0     BrkTil         2        Typ         NaN         NaN
# 2904           0     CBlock         1        Mod       270.0         1.0
#
#       GrLivArea  HalfBath Heating HeatingQC HouseStyle    Id  KitchenAbvGr  \
# 1555       1224         1    GasA        Gd     1.5Fin  1556             1
# 1915        810         0    GasA        TA     1Story  1916             1
# 1945       1474         0    GasA        TA     1Story  1946             1
# 2120        896         0    GasA        TA     1Story  2121             1
# 2151       1518         0    GasA        Ex     1Story  2152             1
# 2188       3820         1    GasA        TA     1Story  2189             1
# 2216        733         0    Wall        Po     1Story  2217             1
# 2250       1836         0    GasA        Ex     2.5Unf  2251             1
# 2473       1484         0    GasA        Fa     1.5Fin  2474             1
# 2489       1176         0    GasA        TA     1Story  2490             1
# 2576       1828         0    GasA        Ex     2Story  2577             1
# 2904       1600         1    GasA        TA     1Story  2905             1
#
#      KitchenQual LandContour LandSlope  LotArea LotConfig LotShape  \
# 1555         NaN         Lvl       Gtl    10632    Inside      IR1
# 1915          TA         Lvl       Gtl    21780    Inside      Reg
# 1945          TA         Bnk       Gtl    31220       FR2      IR1
# 2120          TA         Lvl       Gtl     5940       FR3      IR1
# 2151          Fa         Lvl       Gtl    19550    Inside      Reg
# 2188          Ex         Lvl       Gtl    47007    Inside      IR1
# 2216          Fa         Low       Mod    14584    Inside      Reg
# 2250          TA         Low       Gtl    56600    Inside      IR1
# 2473          TA         Lvl       Gtl    10320    Corner      Reg
# 2489          TA         Lvl       Gtl    13770    Corner      Reg
# 2576          Gd         Lvl       Gtl     9060    Inside      Reg
# 2904          TA         Lvl       Gtl    31250    Inside      Reg
#
#       LowQualFinSF  MSSubClass MSZoning  MiscVal  MoSold Neighborhood  \
# 1555             0          50       RL        0       1      ClearCr
# 1915             0          30      NaN        0       3       IDOTRR
# 1945             0          20       RL      750       5      Gilbert
# 2120             0          20       RM        0       4      BrkSide
# 2151             0          30       RL        0       1      Edwards
# 2188             0          20       RL        0       7      Edwards
# 2216             0          20      NaN        0       2       IDOTRR
# 2250             0          70      NaN        0       1       IDOTRR
# 2473           114          50       RM        0       9       IDOTRR
# 2489             0          20       RL        0      10       Sawyer
# 2576             0          70       RM        0       3       IDOTRR
# 2904             0          20      NaN        0       5      Mitchel
#
#       OpenPorchSF  OverallCond  OverallQual PavedDrive  PoolArea RoofMatl  \
# 1555            0            3            5          N         0  CompShg
# 1915           24            4            2          N         0  CompShg
# 1945            0            2            6          Y         0  CompShg
# 2120            0            7            4          Y         0  CompShg
# 2151           39            7            5          Y         0  Tar&Grv
# 2188          372            7            5          Y         0  CompShg
# 2216            0            5            1          N         0  CompShg
# 2250            0            1            5          N         0  CompShg
# 2473          211            1            4          N         0  CompShg
# 2489            0            6            5          Y         0  CompShg
# 2576            0            6            5          Y         0  CompShg
# 2904            0            3            1          N         0  CompShg
#
#      RoofStyle SaleCondition  SalePrice SaleType  ScreenPorch Street  \
# 1555     Gable        Normal        0.0      COD            0   Pave
# 1915     Gable        Normal        0.0    ConLD            0   Grvl
# 1945       Hip        Normal        0.0       WD            0   Pave
# 2120     Gable       Abnorml        0.0    ConLD            0   Pave
# 2151      Flat        Normal        0.0       WD            0   Pave
# 2188     Gable        Normal        0.0       WD            0   Pave
# 2216     Gable       Abnorml        0.0       WD            0   Pave
# 2250       Hip        Normal        0.0       WD            0   Pave
# 2473     Gable       Abnorml        0.0      COD           84   Pave
# 2489     Gable        Normal        0.0      NaN            0   Pave
# 2576     Gable        Alloca        0.0       WD            0   Pave
# 2904     Gable        Normal        0.0       WD            0   Pave
#
#       TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  \
# 1555             6        689.0    AllPub           0       1917
# 1915             4          0.0       NaN         119       1910
# 1945             7       1632.0       NaN           0       1952
# 2120             4          NaN    AllPub           0       1946
# 2151             5       1580.0    AllPub           0       1940
# 2188            11          0.0    AllPub           0       1959
# 2216             4          0.0    AllPub           0       1952
# 2250             7        686.0    AllPub           0       1900
# 2473             6        771.0    AllPub          14       1910
# 2489             6       1158.0    AllPub           0       1958
# 2576             6        859.0    AllPub         174       1923
# 2904             6          0.0    AllPub           0       1951
#
#       YearRemodAdd  YrSold
# 1555          1950    2010
# 1915          1950    2009
# 1945          1952    2008
# 2120          1950    2008
# 2151          2007    2008
# 2188          1996    2008
# 2216          1952    2008
# 2250          1950    2008
# 2473          1950    2007
# 2489          1998    2007
# 2576          1999    2007
# 2904          1951    2006

# %%
# Replace all remaining null values in holdout with median of column

missing = total.loc[:,total.isnull().any()].columns

for col in missing:
    total.loc[total[col].isnull(),col] = total[col].value_counts().argmax()

# %%
total.dtypes
# Out:
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BldgType          object
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# BsmtUnfSF        float64
# CentralAir        object
# Condition1        object
# Condition2        object
# EnclosedPorch      int64
# ExterCond         object
# ExterQual         object
# Exterior1st       object
# Exterior2nd       object
# Fireplaces         int64
# Foundation        object
# FullBath           int64
# Functional        object
# GarageArea       float64
# GarageCars       float64
# GrLivArea          int64
# HalfBath           int64
# Heating           object
# HeatingQC         object
# HouseStyle        object
# Id                 int64
# KitchenAbvGr       int64
# KitchenQual       object
# LandContour       object
# LandSlope         object
# LotArea            int64
# LotConfig         object
# LotShape          object
# LowQualFinSF       int64
# MSSubClass         int64
# MSZoning          object
# MiscVal            int64
# MoSold             int64
# Neighborhood      object
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PavedDrive        object
# PoolArea           int64
# RoofMatl          object
# RoofStyle         object
# SaleCondition     object
# SalePrice        float64
# SaleType          object
# ScreenPorch        int64
# Street            object
# TotRmsAbvGrd       int64
# TotalBsmtSF      float64
# Utilities         object
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# YrSold             int64
# dtype: object

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB, GaussianNB
from sklearn.svm import SVC

# %% [markdown]
# From data_descriptions.txt we can tell what type of data each column is:
#
# Id                int64 - Needed for submission file
# MSSubClass        int64 - Categorical
# MSZoning         object - Categorical
# LotArea           int64 - Continuous
# Street           object - Categorical
# LotShape         object - Categorical
# LandContour      object - Categorical
# Utilities        object - Categorical
# LotConfig        object - Categorical
# LandSlope        object - Categorical
# Neighborhood     object - Categorical
# Condition1       object - Categorical
# Condition2       object - Categorical
# BldgType         object - Categorical
# HouseStyle       object - Categorical
# OverallQual       int64 - Categorical
# OverallCond       int64 - Categorical
# YearBuilt         int64 - Categorical/Continuous
# YearRemodAdd      int64 - Categorical/Continuous
# RoofStyle        object - Categorical
# RoofMatl         object - Categorical
# Exterior1st      object - Categorical
# Exterior2nd      object - Categorical
# ExterQual        object - Categorical
# ExterCond        object - Categorical
# Foundation       object - Categorical
# BsmtFinSF1        int64 - Continuous
# BsmtFinSF2        int64 - Continuous
# BsmtUnfSF         int64 - Continuous
# TotalBsmtSF       int64 - Continuous
# Heating          object - Categorical
# HeatingQC        object - Categorical
# CentralAir       object - Categorical
# 1stFlrSF          int64 - Continuous
# 2ndFlrSF          int64 - Continuous
# LowQualFinSF      int64 - Continuous
# GrLivArea         int64 - Continuous
# BsmtFullBath      int64 - Continuous/Categorical
# BsmtHalfBath      int64 - Continuous/Categorical
# FullBath          int64 - Continuous/Categorical
# HalfBath          int64 - Continuous/Categorical
# BedroomAbvGr      int64 - Continuous/Categorical
# KitchenAbvGr      int64 - Continuous/Categorical
# KitchenQual      object - Categorical
# TotRmsAbvGrd      int64 - Continuous/Categorical
# Functional       object - Categorical
# Fireplaces        int64 - Continuous/Categorical
# GarageCars        int64 - Continuous/Categorical
# GarageArea        int64 - Continuous
# PavedDrive       object - Categorical
# WoodDeckSF        int64 - Continuous
# OpenPorchSF       int64 - Continuous
# EnclosedPorch     int64 - Continuous
# 3SsnPorch         int64 - Continuous
# ScreenPorch       int64 - Continuous
# PoolArea          int64 - Continuous
# MiscVal           int64 - Continuous
# MoSold            int64 - Categorical
# YrSold            int64 - Categorical
# SaleType         object - Categorical
# SaleCondition    object - Categorical
# SalePrice         int64 - Continuous

# %%
# All object columns are categorical and some int64 columns are as well

categorical_cols = list(total.loc[:,total.dtypes=='object'].columns) + ['MSSubClass','OverallQual','OverallCond',
                                                                             'YearBuilt','YearRemodAdd','MoSold',
                                                                             'YrSold','BsmtFullBath','BsmtHalfBath',
                                                                             'FullBath','HalfBath','BedroomAbvGr',
                                                                             'KitchenAbvGr','TotRmsAbvGrd',
                                                                             'Fireplaces','GarageCars']
continuous_cols = [x for x in list(total.columns) if x not in (categorical_cols + ['Id','SalePrice'])]

# %%
def normalize_continuous(df):
    for col in continuous_cols:
        df.loc[:,col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())
    return df

# %%
total = normalize_continuous(total)

# %%
total.head()
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr BldgType  BsmtFinSF1  \
# 0  0.109641  0.413559        0.0             3     1Fam    0.125089
# 1  0.194917  0.000000        0.0             3     1Fam    0.173281
# 2  0.123083  0.419370        0.0             3     1Fam    0.086109
# 3  0.131695  0.366102        0.0             3     1Fam    0.038271
# 4  0.170342  0.509927        0.0             4     1Fam    0.116052
#
#    BsmtFinSF2  BsmtFullBath  BsmtHalfBath  BsmtUnfSF CentralAir Condition1  \
# 0         0.0           1.0           0.0   0.064212          Y       Norm
# 1         0.0           0.0           1.0   0.121575          Y      Feedr
# 2         0.0           1.0           0.0   0.185788          Y       Norm
# 3         0.0           1.0           0.0   0.231164          Y       Norm
# 4         0.0           1.0           0.0   0.209760          Y       Norm
#
#   Condition2  EnclosedPorch ExterCond ExterQual Exterior1st Exterior2nd  \
# 0       Norm       0.000000        TA        Gd     VinylSd     VinylSd
# 1       Norm       0.000000        TA        TA     MetalSd     MetalSd
# 2       Norm       0.000000        TA        Gd     VinylSd     VinylSd
# 3       Norm       0.268775        TA        TA     Wd Sdng     Wd Shng
# 4       Norm       0.000000        TA        Gd     VinylSd     VinylSd
#
#    Fireplaces Foundation  FullBath Functional  GarageArea  GarageCars  \
# 0           0      PConc         2        Typ    0.368280         2.0
# 1           1     CBlock         2        Typ    0.309140         2.0
# 2           1      PConc         2        Typ    0.408602         2.0
# 3           1     BrkTil         1        Typ    0.431452         3.0
# 4           1      PConc         2        Typ    0.561828         3.0
#
#    GrLivArea  HalfBath Heating HeatingQC HouseStyle  Id  KitchenAbvGr  \
# 0   0.259231         1    GasA        Ex     2Story   1             1
# 1   0.174830         0    GasA        Ex     1Story   2             1
# 2   0.273549         1    GasA        Ex     2Story   3             1
# 3   0.260550         0    GasA        Gd     2Story   4             1
# 4   0.351168         1    GasA        Ex     2Story   5             1
#
#   KitchenQual LandContour LandSlope   LotArea LotConfig LotShape  \
# 0          Gd         Lvl       Gtl  0.033420    Inside      Reg
# 1          TA         Lvl       Gtl  0.038795       FR2      Reg
# 2          Gd         Lvl       Gtl  0.046507    Inside      IR1
# 3          Gd         Lvl       Gtl  0.038561    Corner      IR1
# 4          Gd         Lvl       Gtl  0.060576       FR2      IR1
#
#    LowQualFinSF  MSSubClass MSZoning  MiscVal  MoSold Neighborhood  \
# 0           0.0          60       RL      0.0       2      CollgCr
# 1           0.0          20       RL      0.0       5      Veenker
# 2           0.0          60       RL      0.0       9      CollgCr
# 3           0.0          70       RL      0.0       2      Crawfor
# 4           0.0          60       RL      0.0      12      NoRidge
#
#    OpenPorchSF  OverallCond  OverallQual PavedDrive  PoolArea RoofMatl  \
# 0     0.082210            5            7          Y       0.0  CompShg
# 1     0.000000            8            6          Y       0.0  CompShg
# 2     0.056604            5            7          Y       0.0  CompShg
# 3     0.047170            5            7          Y       0.0  CompShg
# 4     0.113208            5            8          Y       0.0  CompShg
#
#   RoofStyle SaleCondition  SalePrice SaleType  ScreenPorch Street  \
# 0     Gable        Normal   208500.0       WD          0.0   Pave
# 1     Gable        Normal   181500.0       WD          0.0   Pave
# 2     Gable        Normal   223500.0       WD          0.0   Pave
# 3     Gable       Abnorml   140000.0       WD          0.0   Pave
# 4     Gable        Normal   250000.0       WD          0.0   Pave
#
#    TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  YearRemodAdd  \
# 0             8     0.140098    AllPub    0.000000       2003          2003
# 1             6     0.206547    AllPub    0.209270       1976          1976
# 2             6     0.150573    AllPub    0.000000       2001          2002
# 3             7     0.123732    AllPub    0.000000       1915          1970
# 4             9     0.187398    AllPub    0.134831       2000          2000
#
#    YrSold
# 0    2008
# 1    2007
# 2    2008
# 3    2006
# 4    2008

# %%
def dummy_categorical(df):
    dummies = pd.get_dummies(df[categorical_cols],columns=categorical_cols)
    df = pd.concat([df,dummies],axis=1)
    df.drop(categorical_cols,axis=1,inplace=True)
    return(df)

# %%
print(total.shape)

total = dummy_categorical(total)

print(total.shape)
# Out:
# (2919, 62)
# (2919, 484)

# %%
pd.options.display.max_rows = 1000
total.dtypes
# Out:
# 1stFlrSF                 float64
# 2ndFlrSF                 float64
# 3SsnPorch                float64
# BsmtFinSF1               float64
# BsmtFinSF2               float64
# BsmtUnfSF                float64
# EnclosedPorch            float64
# GarageArea               float64
# GrLivArea                float64
# Id                         int64
# LotArea                  float64
# LowQualFinSF             float64
# MiscVal                  float64
# OpenPorchSF              float64
# PoolArea                 float64
# SalePrice                float64
# ScreenPorch              float64
# TotalBsmtSF              float64
# WoodDeckSF               float64
# BldgType_1Fam              uint8
# BldgType_2fmCon            uint8
# BldgType_Duplex            uint8
# BldgType_Twnhs             uint8
# BldgType_TwnhsE            uint8
# CentralAir_N               uint8
# CentralAir_Y               uint8
# Condition1_Artery          uint8
# Condition1_Feedr           uint8
# Condition1_Norm            uint8
# Condition1_PosA            uint8
# Condition1_PosN            uint8
# Condition1_RRAe            uint8
# Condition1_RRAn            uint8
# Condition1_RRNe            uint8
# Condition1_RRNn            uint8
# Condition2_Artery          uint8
# Condition2_Feedr           uint8
# Condition2_Norm            uint8
# Condition2_PosA            uint8
# Condition2_PosN            uint8
# Condition2_RRAe            uint8
# Condition2_RRAn            uint8
# Condition2_RRNn            uint8
# ExterCond_Ex               uint8
# ExterCond_Fa               uint8
# ExterCond_Gd               uint8
# ExterCond_Po               uint8
# ExterCond_TA               uint8
# ExterQual_Ex               uint8
# ExterQual_Fa               uint8
# ExterQual_Gd               uint8
# ExterQual_TA               uint8
# Exterior1st_AsbShng        uint8
# Exterior1st_AsphShn        uint8
# Exterior1st_BrkComm        uint8
# Exterior1st_BrkFace        uint8
# Exterior1st_CBlock         uint8
# Exterior1st_CemntBd        uint8
# Exterior1st_HdBoard        uint8
# Exterior1st_ImStucc        uint8
# Exterior1st_MetalSd        uint8
# Exterior1st_Plywood        uint8
# Exterior1st_Stone          uint8
# Exterior1st_Stucco         uint8
# Exterior1st_VinylSd        uint8
# Exterior1st_Wd Sdng        uint8
# Exterior1st_WdShing        uint8
# Exterior2nd_AsbShng        uint8
# Exterior2nd_AsphShn        uint8
# Exterior2nd_Brk Cmn        uint8
# Exterior2nd_BrkFace        uint8
# Exterior2nd_CBlock         uint8
# Exterior2nd_CmentBd        uint8
# Exterior2nd_HdBoard        uint8
# Exterior2nd_ImStucc        uint8
# Exterior2nd_MetalSd        uint8
# Exterior2nd_Other          uint8
# Exterior2nd_Plywood        uint8
# Exterior2nd_Stone          uint8
# Exterior2nd_Stucco         uint8
# Exterior2nd_VinylSd        uint8
# Exterior2nd_Wd Sdng        uint8
# Exterior2nd_Wd Shng        uint8
# Foundation_BrkTil          uint8
# Foundation_CBlock          uint8
# Foundation_PConc           uint8
# Foundation_Slab            uint8
# Foundation_Stone           uint8
# Foundation_Wood            uint8
# Functional_Maj1            uint8
# Functional_Maj2            uint8
# Functional_Min1            uint8
# Functional_Min2            uint8
# Functional_Mod             uint8
# Functional_Sev             uint8
# Functional_Typ             uint8
# Heating_Floor              uint8
# Heating_GasA               uint8
# Heating_GasW               uint8
# Heating_Grav               uint8
# Heating_OthW               uint8
# Heating_Wall               uint8
# HeatingQC_Ex               uint8
# HeatingQC_Fa               uint8
# HeatingQC_Gd               uint8
# HeatingQC_Po               uint8
# HeatingQC_TA               uint8
# HouseStyle_1.5Fin          uint8
# HouseStyle_1.5Unf          uint8
# HouseStyle_1Story          uint8
# HouseStyle_2.5Fin          uint8
# HouseStyle_2.5Unf          uint8
# HouseStyle_2Story          uint8
# HouseStyle_SFoyer          uint8
# HouseStyle_SLvl            uint8
# KitchenQual_Ex             uint8
# KitchenQual_Fa             uint8
# KitchenQual_Gd             uint8
# KitchenQual_TA             uint8
# LandContour_Bnk            uint8
# LandContour_HLS            uint8
# LandContour_Low            uint8
# LandContour_Lvl            uint8
# LandSlope_Gtl              uint8
# LandSlope_Mod              uint8
# LandSlope_Sev              uint8
# LotConfig_Corner           uint8
# LotConfig_CulDSac          uint8
# LotConfig_FR2              uint8
# LotConfig_FR3              uint8
# LotConfig_Inside           uint8
# LotShape_IR1               uint8
# LotShape_IR2               uint8
# LotShape_IR3               uint8
# LotShape_Reg               uint8
# MSZoning_C (all)           uint8
# MSZoning_FV                uint8
# MSZoning_RH                uint8
# MSZoning_RL                uint8
# MSZoning_RM                uint8
# Neighborhood_Blmngtn       uint8
# Neighborhood_Blueste       uint8
# Neighborhood_BrDale        uint8
# Neighborhood_BrkSide       uint8
# Neighborhood_ClearCr       uint8
# Neighborhood_CollgCr       uint8
# Neighborhood_Crawfor       uint8
# Neighborhood_Edwards       uint8
# Neighborhood_Gilbert       uint8
# Neighborhood_IDOTRR        uint8
# Neighborhood_MeadowV       uint8
# Neighborhood_Mitchel       uint8
# Neighborhood_NAmes         uint8
# Neighborhood_NPkVill       uint8
# Neighborhood_NWAmes        uint8
# Neighborhood_NoRidge       uint8
# Neighborhood_NridgHt       uint8
# Neighborhood_OldTown       uint8
# Neighborhood_SWISU         uint8
# Neighborhood_Sawyer        uint8
# Neighborhood_SawyerW       uint8
# Neighborhood_Somerst       uint8
# Neighborhood_StoneBr       uint8
# Neighborhood_Timber        uint8
# Neighborhood_Veenker       uint8
# PavedDrive_N               uint8
# PavedDrive_P               uint8
# PavedDrive_Y               uint8
# RoofMatl_ClyTile           uint8
# RoofMatl_CompShg           uint8
# RoofMatl_Membran           uint8
# RoofMatl_Metal             uint8
# RoofMatl_Roll              uint8
# RoofMatl_Tar&Grv           uint8
# RoofMatl_WdShake           uint8
# RoofMatl_WdShngl           uint8
# RoofStyle_Flat             uint8
# RoofStyle_Gable            uint8
# RoofStyle_Gambrel          uint8
# RoofStyle_Hip              uint8
# RoofStyle_Mansard          uint8
# RoofStyle_Shed             uint8
# SaleCondition_Abnorml      uint8
# SaleCondition_AdjLand      uint8
# SaleCondition_Alloca       uint8
# SaleCondition_Family       uint8
# SaleCondition_Normal       uint8
# SaleCondition_Partial      uint8
# SaleType_COD               uint8
# SaleType_CWD               uint8
# SaleType_Con               uint8
# SaleType_ConLD             uint8
# SaleType_ConLI             uint8
# SaleType_ConLw             uint8
# SaleType_New               uint8
# SaleType_Oth               uint8
# SaleType_WD                uint8
# Street_Grvl                uint8
# Street_Pave                uint8
# Utilities_AllPub           uint8
# Utilities_NoSeWa           uint8
# MSSubClass_20              uint8
# MSSubClass_30              uint8
# MSSubClass_40              uint8
# MSSubClass_45              uint8
# MSSubClass_50              uint8
# MSSubClass_60              uint8
# MSSubClass_70              uint8
# MSSubClass_75              uint8
# MSSubClass_80              uint8
# MSSubClass_85              uint8
# MSSubClass_90              uint8
# MSSubClass_120             uint8
# MSSubClass_150             uint8
# MSSubClass_160             uint8
# MSSubClass_180             uint8
# MSSubClass_190             uint8
# OverallQual_1              uint8
# OverallQual_2              uint8
# OverallQual_3              uint8
# OverallQual_4              uint8
# OverallQual_5              uint8
# OverallQual_6              uint8
# OverallQual_7              uint8
# OverallQual_8              uint8
# OverallQual_9              uint8
# OverallQual_10             uint8
# OverallCond_1              uint8
# OverallCond_2              uint8
# OverallCond_3              uint8
# OverallCond_4              uint8
# OverallCond_5              uint8
# OverallCond_6              uint8
# OverallCond_7              uint8
# OverallCond_8              uint8
# OverallCond_9              uint8
# YearBuilt_1872             uint8
# YearBuilt_1875             uint8
# YearBuilt_1879             uint8
# YearBuilt_1880             uint8
# YearBuilt_1882             uint8
# YearBuilt_1885             uint8
# YearBuilt_1890             uint8
# YearBuilt_1892             uint8
# YearBuilt_1893             uint8
# YearBuilt_1895             uint8
# YearBuilt_1896             uint8
# YearBuilt_1898             uint8
# YearBuilt_1900             uint8
# YearBuilt_1901             uint8
# YearBuilt_1902             uint8
# YearBuilt_1904             uint8
# YearBuilt_1905             uint8
# YearBuilt_1906             uint8
# YearBuilt_1907             uint8
# YearBuilt_1908             uint8
# YearBuilt_1910             uint8
# YearBuilt_1911             uint8
# YearBuilt_1912             uint8
# YearBuilt_1913             uint8
# YearBuilt_1914             uint8
# YearBuilt_1915             uint8
# YearBuilt_1916             uint8
# YearBuilt_1917             uint8
# YearBuilt_1918             uint8
# YearBuilt_1919             uint8
# YearBuilt_1920             uint8
# YearBuilt_1921             uint8
# YearBuilt_1922             uint8
# YearBuilt_1923             uint8
# YearBuilt_1924             uint8
# YearBuilt_1925             uint8
# YearBuilt_1926             uint8
# YearBuilt_1927             uint8
# YearBuilt_1928             uint8
# YearBuilt_1929             uint8
# YearBuilt_1930             uint8
# YearBuilt_1931             uint8
# YearBuilt_1932             uint8
# YearBuilt_1934             uint8
# YearBuilt_1935             uint8
# YearBuilt_1936             uint8
# YearBuilt_1937             uint8
# YearBuilt_1938             uint8
# YearBuilt_1939             uint8
# YearBuilt_1940             uint8
# YearBuilt_1941             uint8
# YearBuilt_1942             uint8
# YearBuilt_1945             uint8
# YearBuilt_1946             uint8
# YearBuilt_1947             uint8
# YearBuilt_1948             uint8
# YearBuilt_1949             uint8
# YearBuilt_1950             uint8
# YearBuilt_1951             uint8
# YearBuilt_1952             uint8
# YearBuilt_1953             uint8
# YearBuilt_1954             uint8
# YearBuilt_1955             uint8
# YearBuilt_1956             uint8
# YearBuilt_1957             uint8
# YearBuilt_1958             uint8
# YearBuilt_1959             uint8
# YearBuilt_1960             uint8
# YearBuilt_1961             uint8
# YearBuilt_1962             uint8
# YearBuilt_1963             uint8
# YearBuilt_1964             uint8
# YearBuilt_1965             uint8
# YearBuilt_1966             uint8
# YearBuilt_1967             uint8
# YearBuilt_1968             uint8
# YearBuilt_1969             uint8
# YearBuilt_1970             uint8
# YearBuilt_1971             uint8
# YearBuilt_1972             uint8
# YearBuilt_1973             uint8
# YearBuilt_1974             uint8
# YearBuilt_1975             uint8
# YearBuilt_1976             uint8
# YearBuilt_1977             uint8
# YearBuilt_1978             uint8
# YearBuilt_1979             uint8
# YearBuilt_1980             uint8
# YearBuilt_1981             uint8
# YearBuilt_1982             uint8
# YearBuilt_1983             uint8
# YearBuilt_1984             uint8
# YearBuilt_1985             uint8
# YearBuilt_1986             uint8
# YearBuilt_1987             uint8
# YearBuilt_1988             uint8
# YearBuilt_1989             uint8
# YearBuilt_1990             uint8
# YearBuilt_1991             uint8
# YearBuilt_1992             uint8
# YearBuilt_1993             uint8
# YearBuilt_1994             uint8
# YearBuilt_1995             uint8
# YearBuilt_1996             uint8
# YearBuilt_1997             uint8
# YearBuilt_1998             uint8
# YearBuilt_1999             uint8
# YearBuilt_2000             uint8
# YearBuilt_2001             uint8
# YearBuilt_2002             uint8
# YearBuilt_2003             uint8
# YearBuilt_2004             uint8
# YearBuilt_2005             uint8
# YearBuilt_2006             uint8
# YearBuilt_2007             uint8
# YearBuilt_2008             uint8
# YearBuilt_2009             uint8
# YearBuilt_2010             uint8
# YearRemodAdd_1950          uint8
# YearRemodAdd_1951          uint8
# YearRemodAdd_1952          uint8
# YearRemodAdd_1953          uint8
# YearRemodAdd_1954          uint8
# YearRemodAdd_1955          uint8
# YearRemodAdd_1956          uint8
# YearRemodAdd_1957          uint8
# YearRemodAdd_1958          uint8
# YearRemodAdd_1959          uint8
# YearRemodAdd_1960          uint8
# YearRemodAdd_1961          uint8
# YearRemodAdd_1962          uint8
# YearRemodAdd_1963          uint8
# YearRemodAdd_1964          uint8
# YearRemodAdd_1965          uint8
# YearRemodAdd_1966          uint8
# YearRemodAdd_1967          uint8
# YearRemodAdd_1968          uint8
# YearRemodAdd_1969          uint8
# YearRemodAdd_1970          uint8
# YearRemodAdd_1971          uint8
# YearRemodAdd_1972          uint8
# YearRemodAdd_1973          uint8
# YearRemodAdd_1974          uint8
# YearRemodAdd_1975          uint8
# YearRemodAdd_1976          uint8
# YearRemodAdd_1977          uint8
# YearRemodAdd_1978          uint8
# YearRemodAdd_1979          uint8
# YearRemodAdd_1980          uint8
# YearRemodAdd_1981          uint8
# YearRemodAdd_1982          uint8
# YearRemodAdd_1983          uint8
# YearRemodAdd_1984          uint8
# YearRemodAdd_1985          uint8
# YearRemodAdd_1986          uint8
# YearRemodAdd_1987          uint8
# YearRemodAdd_1988          uint8
# YearRemodAdd_1989          uint8
# YearRemodAdd_1990          uint8
# YearRemodAdd_1991          uint8
# YearRemodAdd_1992          uint8
# YearRemodAdd_1993          uint8
# YearRemodAdd_1994          uint8
# YearRemodAdd_1995          uint8
# YearRemodAdd_1996          uint8
# YearRemodAdd_1997          uint8
# YearRemodAdd_1998          uint8
# YearRemodAdd_1999          uint8
# YearRemodAdd_2000          uint8
# YearRemodAdd_2001          uint8
# YearRemodAdd_2002          uint8
# YearRemodAdd_2003          uint8
# YearRemodAdd_2004          uint8
# YearRemodAdd_2005          uint8
# YearRemodAdd_2006          uint8
# YearRemodAdd_2007          uint8
# YearRemodAdd_2008          uint8
# YearRemodAdd_2009          uint8
# YearRemodAdd_2010          uint8
# MoSold_1                   uint8
# MoSold_2                   uint8
# MoSold_3                   uint8
# MoSold_4                   uint8
# MoSold_5                   uint8
# MoSold_6                   uint8
# MoSold_7                   uint8
# MoSold_8                   uint8
# MoSold_9                   uint8
# MoSold_10                  uint8
# MoSold_11                  uint8
# MoSold_12                  uint8
# YrSold_2006                uint8
# YrSold_2007                uint8
# YrSold_2008                uint8
# YrSold_2009                uint8
# YrSold_2010                uint8
# BsmtFullBath_0.0           uint8
# BsmtFullBath_1.0           uint8
# BsmtFullBath_2.0           uint8
# BsmtFullBath_3.0           uint8
# BsmtHalfBath_0.0           uint8
# BsmtHalfBath_1.0           uint8
# BsmtHalfBath_2.0           uint8
# FullBath_0                 uint8
# FullBath_1                 uint8
# FullBath_2                 uint8
# FullBath_3                 uint8
# FullBath_4                 uint8
# HalfBath_0                 uint8
# HalfBath_1                 uint8
# HalfBath_2                 uint8
# BedroomAbvGr_0             uint8
# BedroomAbvGr_1             uint8
# BedroomAbvGr_2             uint8
# BedroomAbvGr_3             uint8
# BedroomAbvGr_4             uint8
# BedroomAbvGr_5             uint8
# BedroomAbvGr_6             uint8
# BedroomAbvGr_8             uint8
# KitchenAbvGr_0             uint8
# KitchenAbvGr_1             uint8
# KitchenAbvGr_2             uint8
# KitchenAbvGr_3             uint8
# TotRmsAbvGrd_2             uint8
# TotRmsAbvGrd_3             uint8
# TotRmsAbvGrd_4             uint8
# TotRmsAbvGrd_5             uint8
# TotRmsAbvGrd_6             uint8
# TotRmsAbvGrd_7             uint8
# TotRmsAbvGrd_8             uint8
# TotRmsAbvGrd_9             uint8
# TotRmsAbvGrd_10            uint8
# TotRmsAbvGrd_11            uint8
# TotRmsAbvGrd_12            uint8
# TotRmsAbvGrd_13            uint8
# TotRmsAbvGrd_14            uint8
# TotRmsAbvGrd_15            uint8
# Fireplaces_0               uint8
# Fireplaces_1               uint8
# Fireplaces_2               uint8
# Fireplaces_3               uint8
# Fireplaces_4               uint8
# GarageCars_0.0             uint8
# GarageCars_1.0             uint8
# GarageCars_2.0             uint8
# GarageCars_3.0             uint8
# GarageCars_4.0             uint8
# GarageCars_5.0             uint8
# dtype: object

# %%
from sklearn.feature_selection import RFECV, RFE
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.svm import LinearSVC, SVC

# %%
def rmsle(y, y_pred):
    assert len(y) == len(y_pred)
    terms_to_sum = [(math.log(y_pred[i] + 1) - math.log(y[i] + 1)) ** 2.0 for i,pred in enumerate(y_pred)]
    return (sum(terms_to_sum) * (1.0/len(y))) ** 0.5

def rmsle2(predicted, real):
    sum=0.0
    for x in range(len(predicted)):
        p = np.log(predicted[x]+1)
        r = np.log(real[x]+1)
        sum = sum + (p - r)**2
    return (sum/len(predicted))**0.5

# %%
total = total.loc[:,total.sum()>10]

# %%
'SalePrice' in total[:1460].columns
# Out:
# True

# %%
# train = total[:1460].drop('Id',axis=1)

# split = int(train.shape[0]*0.75)

# X_train = train.loc[:split,train.drop('SalePrice',axis=1).columns]
# X_test = train.loc[split:,train.drop('SalePrice',axis=1).columns]
# y_train = train.loc[:split,train.SalePrice]
# y_test = train.loc[:split,train.SalePrice]

# model = LinearSVC()
# model.fit(X_train,y_train)
# y_pred = model.predict(X_test)

# error = rmsle2(y_pred,y_test)
# print(error)

# %%
# y_test

# %%
model = RandomForestRegressor()
features_rmsles = []
for i in range(10,300,10):
    X = total.loc[:1460,:].drop(['Id','SalePrice'],axis=1)
    y = total.loc[:1460,'SalePrice']
    selector = RFE(model,n_features_to_select=i,step=0.1)
#     print('fitting rfe')
    selector.fit(X,y)
#     print('fitted rfe')
    final_features = list(X.columns[selector.support_])
#     print('num features: {}'.format(len(final_features)))

    X = X[final_features]

    kf = KFold(n_splits=5)

    rmsles = []
    for train_indecies, test_indecies in kf.split(X):
#         print("k count: {}".format(len(rmses)+1))
        X_train, X_test = X.loc[train_indecies], X.loc[test_indecies]
        y_train, y_test = y.loc[train_indecies], y.loc[test_indecies]

        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        rmslee = rmsle2(y_test.values,y_pred)
        rmsles.append(rmslee)
    print('num features: {}, rmse: {}'.format(i,np.mean(rmsles)))
    features_rmsles.append(np.mean(rmsles))
#     print(X.shape,'\n\n')
# Out:
# num features: 10, rmse: 0.2914511091675801
# num features: 20, rmse: 0.2893252951463624
# num features: 30, rmse: 0.2752929936185756
# num features: 40, rmse: 0.2799258995720339
# num features: 50, rmse: 0.2742177293276188
# num features: 60, rmse: 0.27483521069814615
# num features: 70, rmse: 0.2758128828725536
# num features: 80, rmse: 0.2741164996432531
# num features: 90, rmse: 0.2705821107142128
# num features: 100, rmse: 0.27342358763951913
# num features: 110, rmse: 0.2713960882223376
# num features: 120, rmse: 0.27485833936943627
# num features: 130, rmse: 0.2725383631358412
# num features: 140, rmse: 0.26992416126203167
# num features: 150, rmse: 0.2735249495686218
# num features: 160, rmse: 0.2735971397837552
# num features: 170, rmse: 0.27159179265810485
# num features: 180, rmse: 0.2748915821926962
# num features: 190, rmse: 0.2771251971559482
# num features: 200, rmse: 0.2739979268634367
# num features: 210, rmse: 0.27261166997305797
# num features: 220, rmse: 0.2719875614775973
# num features: 230, rmse: 0.27117303105963975
# num features: 240, rmse: 0.2739031344356755
# num features: 250, rmse: 0.2709724903036703
# num features: 260, rmse: 0.27327904681982856
# num features: 270, rmse: 0.2732414352837999
# num features: 280, rmse: 0.27445092677456107
# num features: 290, rmse: 0.2725678245255177

# %%
plt.plot(features_rmses)

# %%
np.min(features_rmses)

# %%
X = total.loc[:1460,:].drop(['Id','SalePrice'],axis=1)
y = total.loc[:1460,'SalePrice']

selector = RFE(model,n_features_to_select=120,step=0.1)
selector.fit(X,y)
final_features = list(X.columns[selector.support_])

X = X[final_features]

model.fit(X,y)

holdout_pred = model.predict(total.loc[1460:,final_features])
submission = pd.DataFrame({'Id':holdout.Id,'SalePrice':holdout_pred})
submission.to_csv('submission.csv',index=False)
